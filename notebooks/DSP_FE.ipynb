# %%
import os
import sys

# %%
# os.chdir('/mnt/aclp-vocalis/22032020/1000/21-03-2020/1584811563723-example-voice-sample/')
# os.chdir('/home/linuxu/augury/')
os.getcwd()
# os.listdir()
# Out:
# '/Users/orinegri/covid19/notebooks'

# %%
# from pydub import AudioSegment
# audio = AudioSegment.from_file('play.wav')
# audio = AudioSegment.from_file('../data/play.wav')

# %%
from scipy.io import wavfile
fs, data = wavfile.read('../data/play.wav')

# %%
import matplotlib.pyplot as plt
plt.plot(data[:,0])

# %%
data.shape
fs
# Out:
# 44100

# %%
from scipy.fftpack import fft, ifft
import numpy as np
x=data[:,0]
L=len(x)
T=L/fs
sx=1/L*fft(x)
s=np.abs(sx[:int(L/2)])
f=np.linspace(0,fs/2,fs/2*T)
print(f.shape)
print(s.shape)
# Out:
# (144384,)
# (144384,)
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:8: DeprecationWarning: object of type <class 'float'> cannot be safely interpreted as an integer.

# %%
plt.plot(f,s)
plt.xlim(500,600)
f[-1]
# Out:
# 22050.0

# %%
# basic feature extraction
x['features'] = utils.features.signal_features(x)

# %%
tdfeatures
# Out:
# __main__.tdfeatures
